# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_Players = pd.read_csv('Players.csv')
df_Players.sample(5)
# Out:
#       Year     Player_Name Matches_Batted Not_Outs Runs_Scored Highest_Score  \
# 563   2023     Amit Mishra              7        0          19            19
# 470   2021        KL Rahul             13        3         626           98*
# 713   2022   Jitesh Sharma             12        2         234            44
# 374   2018     Rinku Singh              4        0          29            16
# 1071  2018  Mayank Agarwal             11        1         120            30
#
#      Batting_Average Balls_Faced Batting_Strike_Rate Centuries  ...  \
# 563               19          30               63.33         0  ...
# 470             62.6         451               138.8         0  ...
# 713            29.25         143              163.64         0  ...
# 374             7.25          31               93.54         0  ...
# 1071              12          94              127.65         0  ...
#
#      Matches_Bowled Balls_Bowled Runs_Conceded Wickets_Taken  \
# ...

# %%
df_Auction = pd.read_csv('Auction.csv')
df_Auction.sample(5)
# Out:
#      Unnamed: 0            Player Base Price         TYPE  COST IN ₹ (CR.)  \
# 556         556  Ottneil Baartman    20 Lakh       BOWLER              NaN
# 514         514          Amit Ali    20 Lakh  ALL-ROUNDER              NaN
# 298         298    Shivam Chauhan    20 Lakh       BATTER              NaN
# 271         271         Vasu Vats    20 Lakh       BOWLER              NaN
# 449         449        M Nidheesh    20 Lakh       BOWLER              NaN
#
#      Cost IN $ (000) 2021 Squad    Team
# 556              NaN        NaN  Unsold
# 514              NaN        NaN  Unsold
# 298              NaN        NaN  Unsold
# 271              NaN        NaN  Unsold
# 449              NaN        NaN  Unsold

# %%
df_Players.describe()
# Out:
#         Year   Player_Name Matches_Batted Not_Outs Runs_Scored Highest_Score  \
# count   1172          1172           1172     1172        1172          1172
# unique    18           247             21       12         389           222
# top     2023  Rohit Sharma             14        0           0             0
# freq     162            17            170      421         179           148
#
#        Batting_Average Balls_Faced Batting_Strike_Rate Centuries  ...  \
# count             1172        1172                1172      1172  ...
# unique             576         329                 712         6  ...
# top                  0           0                   0         0  ...
# freq               171         131                 127      1094  ...
#
#        Matches_Bowled Balls_Bowled Runs_Conceded Wickets_Taken  \
# count            1172         1172          1172          1172
# unique             21          222           363            31
# ...

# %%
df_Auction.describe()
# Out:
#        Unnamed: 0  COST IN ₹ (CR.)  Cost IN $ (000)
# count  633.000000       237.000000       237.000000
# mean   316.000000         3.695781       480.451477
# std    182.875641         4.238092       550.951945
# min      0.000000         0.200000        26.000000
# 25%    158.000000         0.400000        52.000000
# 50%    316.000000         1.900000       247.000000
# 75%    474.000000         6.500000       845.000000
# max    632.000000        17.000000      2210.000000

# %%
df_Players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1172 entries, 0 to 1171
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 1172 non-null   object
#  1   Player_Name          1172 non-null   object
#  2   Matches_Batted       1172 non-null   object
#  3   Not_Outs             1172 non-null   object
#  4   Runs_Scored          1172 non-null   object
#  5   Highest_Score        1172 non-null   object
#  6   Batting_Average      1172 non-null   object
#  7   Balls_Faced          1172 non-null   object
#  8   Batting_Strike_Rate  1172 non-null   object
#  9   Centuries            1172 non-null   object
#  10  Half_Centuries       1172 non-null   object
#  11  Fours                1172 non-null   object
#  12  Sixes                1172 non-null   object
#  13  Catches_Taken        1172 non-null   object
#  14  Stumpings            1172 non-null   object
# ...

# %%
df_Auction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 633 entries, 0 to 632
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       633 non-null    int64
#  1   Player           633 non-null    object
#  2   Base Price       633 non-null    object
#  3   TYPE             633 non-null    object
#  4   COST IN ₹ (CR.)  237 non-null    float64
#  5   Cost IN $ (000)  237 non-null    float64
#  6   2021 Squad       199 non-null    object
#  7   Team             633 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 39.7+ KB

# %%
Type = df_Auction[['Player' , 'TYPE' , 'COST IN ₹ (CR.)']]

# %%
Type.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 633 entries, 0 to 632
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Player           633 non-null    object
#  1   TYPE             633 non-null    object
#  2   COST IN ₹ (CR.)  237 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 15.0+ KB

# %%
print(Type)
# Out:
#                      Player         TYPE  COST IN ₹ (CR.)
# 0               Rashid Khan       BOWLER             15.0
# 1             Hardik Pandya  ALL-ROUNDER             15.0
# 2           Lockie Ferguson       BOWLER             10.0
# 3             Rahul Tewatia  ALL-ROUNDER              9.0
# 4              Shubman Gill       BATTER              8.0
# ..                      ...          ...              ...
# 628            Sairaj Patil       BATTER              NaN
# 629              Monu Singh       BOWLER              NaN
# 630  Nivethan Radhakrishnan       BOWLER              NaN
# 631            Lance Morris       BOWLER              NaN
# 632            Aaron Hardie  ALL-ROUNDER              NaN
#
# [633 rows x 3 columns]

# %%
df_Players_2022 = df_Players[df_Players['Year']=='2022']
df_Players_2022.sample()
# Out:
#      Year   Player_Name Matches_Batted Not_Outs Runs_Scored Highest_Score  \
# 507  2022  Deepak Hooda             15        0         451            59
#
#     Batting_Average Balls_Faced Batting_Strike_Rate Centuries  ...  \
# 507           32.21         330              136.67         0  ...
#
#     Matches_Bowled Balls_Bowled Runs_Conceded Wickets_Taken  \
# 507             15           24            43             1
#
#     Best_Bowling_Match Bowling_Average Economy_Rate Bowling_Strike_Rate  \
# 507               1/31           43.00        10.75               24.00
#
#     Four_Wicket_Hauls Five_Wicket_Hauls
# 507                 0                 0
#
# [1 rows x 25 columns]

# %%
batsmen = df_Auction[df_Auction['TYPE'] == 'BATTER']
batsmen.sample()
# Out:
#      Unnamed: 0          Player Base Price    TYPE  COST IN ₹ (CR.)  \
# 482         482  Bhupen Lalwani    20 Lakh  BATTER              NaN
#
#      Cost IN $ (000) 2021 Squad    Team
# 482              NaN        NaN  Unsold

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 batsmen = pd.merge([df_Players,batsmen])
#       2 batsmen.sample()
#
# TypeError: merge() missing 1 required positional argument: 'right'
